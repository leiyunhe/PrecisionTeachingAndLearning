# %%
import json
import requests

# Authentication for user filing issue (must have read/write access to
# repository to add issue to)
USERNAME = 'leiyunhe'
PASSWORD = 'Craney20150421'

# The repository to add this issue to
REPO_OWNER = 'leiyunhe'
REPO_NAME = 'PrecisionTeachingAndLearning'

# issue created by creator
CREATOR = 'ruibofeng'
TIME = '2017-01-01T00:00:00Z'
payload = {'creator':CREATOR,
			'since':TIME}

def get_github_issue():
	url = 'https://api.github.com/repos/%s/%s/issues' % (REPO_OWNER, REPO_NAME)
	s = requests.session()

	s.auth = (USERNAME,PASSWORD)
 #   issue = {'creator':creator,'since':since,'state':state}
	r = s.get(url, params = payload)
#	print(r.text)
#	print(r.text[0])
	result = json.loads(r.text)
#	print(type(result))
#	return result[0][0]
	# print(result[0])
	issue_id = result[0]["id"]
	issue_number = result[0]["number"]

	print(issue_id,issue_number)
	return issue_id, issue_number




get_github_issue()
# Out:
# 213575747 7
# (213575747, 7)

# %%
import json
import requests

# Authentication for user filing issue (must have read/write access to
# repository to add issue to)
USERNAME = 'leiyunhe'
PASSWORD = 'Craney20150421'

# The repository to add this issue to
REPO_OWNER = 'AIMinder'
REPO_NAME = 'Py103'

# issue created by creator
CREATOR = 'ruibofeng'
TIME = '2017-01-01T00:00:00Z'
payload = {'filter':all,
			'role':all}

ORG_NAME = 'AIMINDER'

# GET /orgs/:org/members
def get_github_member_from_org():
	url = 'https://api.github.com/orgs/%s/members' % (ORG_NAME)
	s = requests.session()

	s.auth = (USERNAME,PASSWORD)
	r = s.get(url, params = payload)
#     r =  s.get(url)
#	print(r.text)
#	print(r.text[0])
	result = json.loads(r.text)
#	print(type(result))

#	return result[0][0]
	print(result[0])

get_github_member_from_org()
# Out:
# {'login': '13416136446', 'id': 20377303, 'avatar_url': 'https://avatars2.githubusercontent.com/u/20377303?v=3', 'gravatar_id': '', 'url': 'https://api.github.com/users/13416136446', 'html_url': 'https://github.com/13416136446', 'followers_url': 'https://api.github.com/users/13416136446/followers', 'following_url': 'https://api.github.com/users/13416136446/following{/other_user}', 'gists_url': 'https://api.github.com/users/13416136446/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/13416136446/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/13416136446/subscriptions', 'organizations_url': 'https://api.github.com/users/13416136446/orgs', 'repos_url': 'https://api.github.com/users/13416136446/repos', 'events_url': 'https://api.github.com/users/13416136446/events{/privacy}', 'received_events_url': 'https://api.github.com/users/13416136446/received_events', 'type': 'User', 'site_admin': False}

# %%
# 仅能输出cricksong发布的最新issue，需要考虑使用循环，将所有的结果保存到list中

import json
import requests

# Authentication for user filing issue (must have read/write access to
# repository to add issue to)
USERNAME = 'leiyunhe'
PASSWORD = 'Craney20150421'

# The repository to add this issue to
REPO_OWNER = 'AIMinder'
REPO_NAME = 'Py103'

# issue created by creator
CREATOR = 'CrickeySong'
TIME = '2017-03-01T00:00:00Z'
payload = {'creator':CREATOR,
			'since':TIME}

def get_github_issue():
	url = 'https://api.github.com/repos/%s/%s/issues' % (REPO_OWNER, REPO_NAME)
	s = requests.session()

	s.auth = (USERNAME,PASSWORD)
 #   issue = {'creator':creator,'since':since,'state':state}
	r = s.get(url, params = payload)
#	print(r.text)
#	print(r.text[0])
	result = json.loads(r.text)
#	print(type(result))
#	return result[0][0]
# 	print(result)
	issue_id = result[0]["id"]
	issue_number = result[0]["number"]
	return (issue_id, issue_number)

r = get_github_issue()
print(r)
# Out:
# (210461387, 267)

# %%
# 仅能输出cricksong发布的最新issue，需要考虑使用循环，将所有的结果保存到list中

import json
import requests

# Authentication for user filing issue (must have read/write access to
# repository to add issue to)
USERNAME = 'leiyunhe'
PASSWORD = 'Craney20150421'

# The repository to add this issue to
REPO_OWNER = 'AIMinder'
REPO_NAME = 'Py103'

# issue created by creator
CREATOR = 'CrickeySong'
TIME = '2017-03-01T00:00:00Z'
payload = {'creator':CREATOR,
			'since':TIME}

def get_github_issue():
	url = 'https://api.github.com/repos/%s/%s/issues' % (REPO_OWNER, REPO_NAME)
	s = requests.session()

	s.auth = (USERNAME,PASSWORD)
 #   issue = {'creator':creator,'since':since,'state':state}
	r = s.get(url, params = payload)
#	print(r.text)
#	print(r.text[0])
	result = json.loads(r.text)
#	print(type(result))
#	return result[0][0]
    for l in result:
        print(l["id"],l["number"])
#         issue_number = l["number"]
# 	issue_id = result[0]["id"]
# 	issue_number = result[0]["number"]
    
# 	print(issue_id,issue_number)
# 	return (issue_id, issue_number)


get_github_issue()
# r = get_github_issue()
# print(r)
# Out:
#   File "<ipython-input-27-3410c5bdab11>", line 33
#     for l in result:
#                     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# 仅能输出cricksong发布的最新issue，需要考虑使用循环，将所有的结果保存到list中

import json
import requests

# Authentication for user filing issue (must have read/write access to
# repository to add issue to)
USERNAME = 'leiyunhe'
PASSWORD = 'Craney20150421'

# The repository to add this issue to
REPO_OWNER = 'AIMinder'
REPO_NAME = 'Py103'

# issue created by creator
CREATOR = 'CrickeySong'
TIME = '2017-03-01T00:00:00Z'
payload = {'creator':CREATOR,
           'since':TIME}

def get_github_issue():
    url = 'https://api.github.com/repos/%s/%s/issues' % (REPO_OWNER, REPO_NAME)
    s = requests.session()
    s.auth = (USERNAME,PASSWORD)
    r = s.get(url, params = payload)
    result = json.loads(r.text)
    for l in result:
        print(l["id"],l["number"])

get_github_issue()
# Out:
# 210461387 267
# 210454026 266
# 210453605 265
# 210453217 264
# 210452648 263
# 208711794 242
# 206970172 221

# %%
# 通过第一个issue，下载py103的学员索引

import json
import requests

# Authentication for user filing issue (must have read/write access to
# repository to add issue to)
USERNAME = 'leiyunhe'
PASSWORD = 'Craney20150421'

# The repository to add this issue to
REPO_OWNER = 'AIMinder'
REPO_NAME = 'Py103'

url = 'https://api.github.com/repos/%s/%s/issues/1' % (REPO_OWNER, REPO_NAME)
s = requests.session()
s.auth = (USERNAME,PASSWORD)
r = s.get(url)
result = json.loads(r.text)
print(result)
# Out:
# {'url': 'https://api.github.com/repos/AIMinder/Py103/issues/1', 'repository_url': 'https://api.github.com/repos/AIMinder/Py103', 'labels_url': 'https://api.github.com/repos/AIMinder/Py103/issues/1/labels{/name}', 'comments_url': 'https://api.github.com/repos/AIMinder/Py103/issues/1/comments', 'events_url': 'https://api.github.com/repos/AIMinder/Py103/issues/1/events', 'html_url': 'https://github.com/AIMinder/Py103/issues/1', 'id': 197811275, 'number': 1, 'title': 'Py103 学员索引', 'user': {'login': 'ishanshan', 'id': 8518968, 'avatar_url': 'https://avatars0.githubusercontent.com/u/8518968?v=3', 'gravatar_id': '', 'url': 'https://api.github.com/users/ishanshan', 'html_url': 'https://github.com/ishanshan', 'followers_url': 'https://api.github.com/users/ishanshan/followers', 'following_url': 'https://api.github.com/users/ishanshan/following{/other_user}', 'gists_url': 'https://api.github.com/users/ishanshan/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ishanshan/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ishanshan/subscriptions', 'organizations_url': 'https://api.github.com/users/ishanshan/orgs', 'repos_url': 'https://api.github.com/users/ishanshan/repos', 'events_url': 'https://api.github.com/users/ishanshan/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ishanshan/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 505925514, 'url': 'https://api.github.com/repos/AIMinder/Py103/labels/%E5%85%AC%E5%91%8A', 'name': '公告', 'color': '006b75', 'default': False}], 'state': 'open', 'locked': False, 'assignee': {'login': 'CrickeySong', 'id': 20220119, 'avatar_url': 'https://avatars3.githubusercontent.com/u/20220119?v=3', 'gravatar_id': '', 'url': 'https://api.github.com/users/CrickeySong', 'html_url': 'https://github.com/CrickeySong', 'followers_url': 'https://api.github.com/users/CrickeySong/followers', 'following_url': 'https://api.github.com/users/CrickeySong/following{/other_user}', 'gists_url': 'https://api.github.com/users/CrickeySong/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/CrickeySong/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/CrickeySong/subscriptions', 'organizations_url': 'https://api.github.com/users/CrickeySong/orgs', 'repos_url': 'https://api.github.com/users/CrickeySong/repos', 'events_url': 'https://api.github.com/users/CrickeySong/events{/privacy}', 'received_events_url': 'https://api.github.com/users/CrickeySong/received_events', 'type': 'User', 'site_admin': False}, 'assignees': [{'login': 'CrickeySong', 'id': 20220119, 'avatar_url': 'https://avatars3.githubusercontent.com/u/20220119?v=3', 'gravatar_id': '', 'url': 'https://api.github.com/users/CrickeySong', 'html_url': 'https://github.com/CrickeySong', 'followers_url': 'https://api.github.com/users/CrickeySong/followers', 'following_url': 'https://api.github.com/users/CrickeySong/following{/other_user}', 'gists_url': 'https://api.github.com/users/CrickeySong/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/CrickeySong/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/CrickeySong/subscriptions', 'organizations_url': 'https://api.github.com/users/CrickeySong/orgs', 'repos_url': 'https://api.github.com/users/CrickeySong/repos', 'events_url': 'https://api.github.com/users/CrickeySong/events{/privacy}', 'received_events_url': 'https://api.github.com/users/CrickeySong/received_events', 'type': 'User', 'site_admin': False}], 'milestone': {'url': 'https://api.github.com/repos/AIMinder/Py103/milestones/3', 'html_url': 'https://github.com/AIMinder/Py103/milestone/3', 'labels_url': 'https://api.github.com/repos/AIMinder/Py103/milestones/3/labels', 'id': 2218493, 'number': 3, 'title': 'chaos', 'description': '无截止时间的主题讨论', 'creator': {'login': 'ishanshan', 'id': 8518968, 'avatar_url': 'https://avatars0.githubusercontent.com/u/8518968?v=3', 'gravatar_id': '', 'url': 'https://api.github.com/users/is ...

# %%
names = result["body"].split('|')

# %%
ls = [name.strip() for name in names]
ls
# Out:
# ['~汇总本期课程学员信息，以便同城线下互助。\r\n\r\n## 北京大区',
#  '序号',
#  'GitHub Username',
#  '姓名',
#  '坐标',
#  'E-mail',
#  '性别',
#  '',
#  '----',
#  '----------------------',
#  '-----',
#  '---------',
#  '---------------------------------',
#  '----',
#  '',
#  '1',
#  'VeronicaBai',
#  '白璐',
#  '北京',
#  'bailu03@meituan.com',
#  '女士',
#  '',
#  '2',
#  'Sean-Lu',
#  '陆扬霄',
#  '北京',
#  'i849355052@gmail.com',
#  '先生',
#  '',
#  '3',
#  'Xenaxxx',
#  '徐迅',
#  '北京',
#  'xuxunxx0129@gmail.com',
#  '女士',
#  '',
#  '4',
#  'WentaoSun',
#  '孙文韬',
#  '北京',
#  'sunwentao0322@163.com',
#  '先生',
#  '',
#  '5',
#  'wangh0117',
#  '汪海',
#  '北京',
#  'wanghai14@mails.tsinghua.edu.cn',
#  '先生',
#  '',
#  '6',
#  'gabriel-guobin',
#  '郭斌',
#  '北京',
#  'Gabriel.guobin@gmail.com',
#  '先生',
#  '',
#  '7',
#  'ZephyrG',
#  '关植方',
#  '北京',
#  'zhifang.guan@foxmail.com',
#  '女士',
#  '',
#  '8',
#  'OMlalala',
#  '王琛',
#  '北京',
#  '422173092@qq.com',
#  '先生',
#  '',
#  '9',
#  'MountainDoor',
#  '王玮楠',
#  '北京',
#  'peterwww6@139.com',
#  '先生',
#  '',
#  '10',
#  'chasejwang',
#  '汪健',
#  '北京',
#  'chase.jwang@outlook.com',
#  '先生',
#  '',
#  '11',
#  '13416136446',
#  '李广鹤',
#  '北京',
#  'liguanghe218317@gmail.com',
#  '女士',
#  '',
#  '12',
#  'hunshiouren',
#  '李欣',
#  '北京',
#  'lixinisme1115@126.com',
#  '女士',
#  '',
#  '13',
#  'NeuroYoung',
#  '陆洋',
#  '北京',
#  'runminlyck@gmail.com',
#  '先生',
#  '',
#  '14',
#  'zhangshiyinrunwithcc',
#  '张诗颖',
#  '北京',
#  '981318360@qq.com',
#  '女士',
#  '',
#  '15',
#  'yuu-',
#  '钟煜',
#  '北京',
#  '654683698@qq.com',
#  '先生',
#  '',
#  '16',
#  'juthy1',
#  '巨晓松',
#  '北京',
#  '110500530j@gamil.com',
#  '先生',
#  '',
#  '17',
#  'Wangjunyu',
#  '王浚宇',
#  '北京',
#  'wjyzc@foxmail.com',
#  '先生',
#  '',
#  '18',
#  'alexhooo',
#  '侯陈昊',
#  '北京',
#  'nyylsd@sina.com',
#  '先生',
#  '',
#  '19',
#  'ternknuth',
#  '杨劲',
#  '北京',
#  'ternknuth@qq.com',
#  '先生',
#  '',
#  '20',
#  'vfrbdxf',
#  '董开欣',
#  '北京',
#  '1807603582@qq.com',
#  '女士',
#  '',
#  '21',
#  'wenyan666',
#  '张文燕',
#  '北京',
#  'wenyan.zhang@foxmail.com',
#  '女士',
#  '',
#  '22',
#  'windflyinglx',
#  '李想',
#  '北京',
#  'lixiang_410@foxmail.com',
#  '女士',
#  '',
#  '23',
#  'Geometary',
#  '牛天晓',
#  '北京',
#  '1801938676@qq.com',
#  '先生',
#  '',
#  '24',
#  'TineeOne',
#  '董琛',
#  '北京',
#  'dongchen2015@gmail.com',
#  '女士',
#  '',
#  '25',
#  'elefnt',
#  '妥彦磊',
#  '北京',
#  'tuoyanlei@hotmail.com',
#  '先生',
#  '',
#  '26',
#  'Henryyichao',
#  '侯逸超',
#  '北京',
#  '543423678@qq.com',
#  '先生',
#  '',
#  '27',
#  'yxlbetty',
#  '袁小丽',
#  '北京',
#  'yxl@wiz.cn',
#  '女士',
#  '',
#  '28',
#  'sunshinecx',
#  '陈鑫',
#  '邯郸、北京',
#  '781460009@qq.com',
#  '先生',
#  '',
#  '29',
#  'Pandacoco',
#  '孙荣玥',
#  '京津、秦皇岛',
#  '674052427@qq.com',
#  '女士',
#  '',
#  '30',
#  'liuxianyun5088',
#  '刘仙芸',
#  '天津（居住地）',
#  'liuxianyun5099@163.com',
#  '女士',
#  '## 长三角大区',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '----',
#  '-----------------',
#  '--------',
#  '-------',
#  '--------------------------',
#  '----',
#  '',
#  '序号',
#  'GitHub Username',
#  '姓名',
#  '坐标',
#  'E-mail',
#  '性别',
#  '',
#  '1',
#  'Ricardotang',
#  '华翌辰',
#  '杭州',
#  'dakeshuide@gmail.com',
#  '先生',
#  '',
#  '2',
#  'Torrtoy',
#  '鲍海峰',
#  '杭州',
#  '787957300@qq.com',
#  '先生',
#  '',
#  '3',
#  'shippomiru',
#  '胡雅晨',
#  '杭州',
#  '297029445@qq.com',
#  '女士',
#  '',
#  '4',
#  'otomobao',
#  '宝志强',
#  '杭州',
#  '17181708@qq.com',
#  '先生',
#  '',
#  '5',
#  'fandongdong89',
#  '范冬冬',
#  '杭州',
#  '809385567@qq.com',
#  '女士',
#  '',
#  '6',
#  'shereb',
#  '王波',
#  '杭州',
#  'wb123@zju.edu.cn',
#  '先生',
#  '',
#  '7',
#  'tcfh2016',
#  '陈联兵',
#  '杭州',
#  'lianbch@gmail.com',
#  '先生',
#  '',
#  '8',
#  'njlhtianwen',
#  '王天闻',
#  '南京',
#  '392476430@qq.com',
#  '先生',
#  '',
#  '9',
#  'Liumang',
#  '刘佳祯',
#  '南京',
#  '61710284@qq.com',
#  '先生',
#  '',
#  '10',
#  'cenweiwei',
#  '岑微微',
#  '宁波',
#  'cenweiwei@gmail.com',
#  '女士',
#  '',
#  '11',
#  'betterMax',
#  '冯雨田',
#  '宁波',
#  'fyt_311@126.com',
#  '先生',
#  '',
#  '12',
#  'Leohb',
#  '廖鸿博',
#  '上海',
#  'lhb_6031@qq.com',
#  '先生',
#  '',
#  '13',
#  'lborodynamo',
#  '田超',
#  '上海',
#  'ronnie.tian@a-carbon.com',
#  '先生',
#  '',
#  '14',
#  'chousawa',
#  '张爽',
#  '上海',
#  '779583547@qq.com',
#  '女士',
#  '',
#  '15',
#  'chuanwj',
#  '王金川',
#  '上海',
#  'chuanwj@163.com',
#  '先生',
#  '',
#  '16',
#  'leilayanhui',
#  '严蕙',
#  '上海',
#  'leilayanhui@sina.com',
#  '女士',
#  '',
#  '17',
#  'Ming-Ding',
#  '丁明',
#  '上海',
#  'joding0000@hotmail.com',
#  '女士',
#  '',
#  '18',
#  'yanzhiw',
#  '刘和宇',
#  '上海',
#  'yanzhiw@gmail.com',
#  '先生',
#  '',
#  '19',
#  'leiyunhe',
#  '雷云鹤',
#  '上海',
#  'yunhe.lei@gmail.com',
#  '女士',
#  '',
#  '20',
#  'yanli-2016',
#  '严礼',
#  '上海',
#  'yanli201051@163.com',
#  '先生',
#  '',
#  '21',
#  'yiiina',
#  '蒋祎娜',
#  '上海',
#  '524117060@qq.com',
#  '女士',
#  '',
#  '22',
#  'VyGiBe',
#  '王健',
#  '上海',
#  'xxlsyq@foxmail.com',
#  '先生',
#  '',
#  '23',
#  'SecZhujun',
#  '朱俊',
#  '上海',
#  'seczhujun@vip.sina.com',
#  '先生',
#  '',
#  '24',
#  'ken0709',
#  '倪利烽',
#  '上海',
#  '86543332@qq.com',
#  '先生',
#  '',
#  '25',
#  'SophieXS',
#  'SoPhie',
#  '上海',
#  '251578821@qq.com',
#  '女士',
#  '',
#  '26',
#  'francesyh',
#  '方溢涵',
#  '上海',
#  '371467702@qq.com',
#  '女士',
#  '',
#  '27',
#  'goldandelion',
#  'yusi',
#  '上海',
#  '2209007118@qq.com',
#  '女士',
#  '',
#  '28',
#  'elsaxxx',
#  '夏晓宣',
#  '上海',
#  '354401906@qq.com',
#  '女士',
#  '',
#  '29',
#  'xuewenqi',
#  '薛文琦',
#  '上海',
#  'xwqiqiqi@icloud.com',
#  '女士',
#  '',
#  '30',
#  'meepochen',
#  '陈铭',
#  '上海',
#  '87437993@qq.com',
#  '先生',
#  '',
#  '31',
#  'Davidfupenghao',
#  '付鹏昊',
#  '上海',
#  'fupenghao@outlook.com',
#  '先生',
#  '',
#  '32',
#  'txytju',
#  '田兴业',
#  '上海',
#  'xingye_tian@tju.edu.cn',
#  '先生',
#  '',
#  '33',
#  'sophiefschen',
#  '陈芳殊',
#  '上海',
#  'sophiefschen@sina.com',
#  '女士',
#  '',
#  '34',
#  'Lesley19',
#  '张瑞',
#  '上海',
#  'Lesley16@gmail.com',
#  '女士',
#  '',
#  '35',
#  'Yifan127',
#  '张一帆',
#  '上海',
#  'yifan127@gmail.com',
#  '女士',
#  '',
#  '36',
#  'leomax01',
#  'leo',
#  '上海',
#  '15900490940@139.com',
#  '先生',
#  '',
#  '37',
#  'mcbub',
#  '徐蜀辰',
#  '上海',
#  'xushuchen@gmail.com',
#  '先生',
#  '',
#  '38',
#  'yzlovekid',
#  '陆颖之',
#  '上海',
#  'yzlovekid@gmail.com',
#  '女士',
#  '',
#  '39',
#  'Zxlon',
#  '周绪龙',
#  '上海、江浙',
#  'ymeiorg@gmail.com',
#  '先生',
#  '',
#  '40',
#  'JunPi',
#  '皮君',
#  '上海、郑州',
#  'balancepot@gmail.com',
#  '先生',
#  '',
#  '41',
#  'irene6161',
#  '六一（刘怡）',
#  '苏州',
#  '1976046205@qq.com',
#  '女士',
#  '',
#  '42',
#  'Vernunftsoft',
#  '张云帆',
#  '苏州',
#  'vernunft@foxmail.com',
#  '先生',
#  '',
#  '43',
#  'hhxjycl',
#  '袁长亮',
#  '苏州',
#  '41022614@qq.com',
#  '先生',
#  '',
#  '44',
#  'JonasCynical',
#  '赵健',
#  '苏州、徐州',
#  'JonasCynical@hotmail.com',
#  '先生',
#  '',
#  '45',
#  'CallingCrab',
#  '何惜露',
#  '温州',
#  '23645508@qq.com',
#  '女士',
#  '',
#  '46',
#  'draachen',
#  '李小龙',
#  '无锡',
#  'brucelxl@qq.com',
#  '先生',
#  '',
#  '47',
#  'starsCX',
#  '成星',
#  '无锡',
#  'starscx@qq.com',
#  '先生',
#  '## 珠三角大区',
#  '序号',
#  'GitHub Username',
#  '姓名',
#  '坐标',
#  'E-mail',
#  '性别',
#  '',
#  '----',
#  '-----------------',
#  '-------',
#  '----------',
#  '-------------------------',
#  '----',
#  '',
#  '1',
#  'lsl1415',
#  '卢舜龙',
#  '汕头',
#  'stlsl@outlook.com',
#  '先生',
#  '',
#  '2',
#  'Twanjun',
#  '汤婉君',
#  '汕头',
#  '847647495@qq.com',
#  '女士',
#  '',
#  '3',
#  'HerbertAChen',
#  '陈光前',
#  '佛山',
#  'u8800cgq@gmail.com',
#  '先生',
#  '',
#  '4',
#  'CarefreeLee',
#  '李得阳',
#  '惠州',
#  '327403606@qq.com',
#  '先生',
#  '',
#  '5',
#  'sardine2',
#  '莫欣妮',
#  '广州',
#  'sardine2@gmail.com',
#  '女士',
#  '',
#  '6',
#  'tyfff',
#  '谭永菲',
#  '广州',
#  'tyf6918@qq.com',
#  '女士',
#  '',
#  '7',
#  '17days',
#  '刘华龙',
#  '广州',
#  'noyliu@qq.com',
#  '先生',
#  '',
#  '8',
#  'simpleowen',
#  '黄文',
#  '广州',
#  'deardamao@gmail.com',
#  '先生',
#  '',
#  '9',
#  'gzMichael',
#  '陈宁',
#  '广州',
#  '1960809@qq.com',
#  '先生',
#  '',
#  '10',
#  'ceciliacheng',
#  '程晓琳',
#  '广州',
#  '1772979678@qq.com',
#  '女士',
#  '',
#  '11',
#  'shi1234',
#  '罗坚实',
#  '广州',
#  'ljshi123@foxmail.com',
#  '先生',
#  '',
#  '12',
#  'guoyuming',
#  '郭雨明',
#  '广州',
#  '410545341@qq.com',
#  '先生',
#  '',
#  '13',
#  'EattheSun',
#  '张昀',
#  '广州，深圳',
#  'eatthesun0319@gmail.com',
#  '女士',
#  '',
#  '14',
#  'linfeng365',
#  '林峰',
#  '广州、深圳、中山',
#  'linfeng82@qq.com',
#  '先生',
#  '',
#  '15',
#  'HenryLGL',
#  '陆国亮',
#  '广州、清远',
#  '945353116@qq.com',
#  '先生',
#  '',
#  '16',
#  'derek-cheng',
#  'derek',
#  '广州、北京',
#  'derek@viewteam.cn',
#  '先生',
#  '',
#  '17',
#  'dersonnex',
#  '许晨风',
#  '深圳',
#  'dersonnex@outlook.com',
#  '女士',
#  '',
#  '18',
#  'panfeng3141',
#  '徐攀峰',
#  '深圳',
#  '1131308065@qq.com',
#  '女士',
#  '',
#  '19',
#  'gogu',
#  '王重阳',
#  '深圳',
#  'Gogu9909@gmail.com',
#  '先生',
#  '',
#  '20',
#  'lying87',
#  '罗颖',
#  '深圳',
#  '604065312@qq.com',
#  '女士',
#  '',
#  '21',
#  'summerpenguin',
#  '赵子涵',
#  '深圳',
#  'zhzhzo@hotmail.com',
#  '女士',
#  '',
#  '22',
#  'mxclover',
#  '明星',
#  '深圳',
#  'mingx.py@qq.com',
#  '先生',
#  '',
#  '23',
#  'Tina-Tiian',
#  '田苗',
#  '中山',
#  '380626617@qq.com',
#  '女士',
#  '',
#  '24',
#  'Tracy-CUHK',
#  '李如',
#  '深圳',
#  'lirutracy@hotmail.com',
#  '女士',
#  '',
#  '25',
#  'LiuArthur',
#  '刘时元',
#  '深圳',
#  '771604530@qq.com',
#  '先生',
#  '',
#  '26',
#  'scratlzj',
#  '刘正杰',
#  '深圳',
#  'scratlzj@gmail.com',
#  '先生',
#  '## 其他地区',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '----',
#  '-----------------',
#  '-------------',
#  '-----------',
#  '--------------------------',
#  '----',
#  '',
#  '序号',
#  'GitHub Username',
#  '姓名',
#  '坐标',
#  'E-mail',
#  '性别',
#  '',
#  '1',
#  'tamuleifan',
#  '樊磊',
#  '北京、休斯顿',
#  'heufanlei@gmail.com',
#  '先生',
#  '',
#  '2',
#  'BravoCiao',
#  '曹欢',
#  '伯明翰、南京、上海',
#  'cieloc@sina.com',
#  '女士',
#  '',
#  '3',
#  'aciie',
#  '刘清玉',
#  '成都',
#  '423780823@qq.com',
#  '女士',
#  '',
#  '4',
#  'hstaoqian',
#  '陶迁',
#  '成都',
#  'hstaoqian@me.com',
#  '先生',
#  '',
#  '5',
#  'YCR007',
#  '袁春蓉',
#  '成都',
#  '2199553410@qq.com',
#  '女士',
#  '',
#  '6',
#  'vanxv',
#  '许从从',
#  '成都、上海',
#  'ironvanxv@gmail.com',
#  '先生',
#  '',
#  '7',
#  'xbaiyuan',
#  '柳白猿',
#  '福冈',
#  'soulfighter163@gmail.com',
#  '先生',
#  '',
#  '8',
#  'NBR-hugh',
#  '倪必荣',
#  '福州、 武汉',
#  '574168029@qq.com',
#  '先生',
#  '',
#  '9',
#  'fatfox2016',
#  '武黎',
#  '阜阳',
#  '15345586621@189.cn',
#  '先生',
#  '',
#  '10',
#  'code661',
#  '谭笃志',
#  '湖南株洲',
#  'tan_661@icloud.com',
#  '先生',
#  '',
#  '11',
#  'luckysilly',
#  '孙祎',
#  '济南',
#  '894779586@qq.com',
#  '女士',
#  '',
#  '12',
#  'MagicCheng',
#  '于耀程',
#  '辽阳',
#  '569326782@qq.com',
#  '先生',
#  '',
#  '13',
#  'hwast',
#  '刘懿遥',
#  '洛杉矶',
#  'elle95@qq.com',
#  '女士',
#  '',
#  '14',
#  'serenechen',
#  'Serene Chen',
#  '密西沙加，多伦多',
#  'seeyu.chen@gmail.com',
#  '女士',
#  '',
#  '15',
#  'stonemask',
#  '王琦',
#  '南昌、厦门',
#  'stonemask@foxmail.com',
#  '先生',
#  '',
#  '16',
#  'livingworld',
#  '赖河涛',
#  '南宁',
#  '455412741@qq.com',
#  '先生',
#  '',
#  '17',
#  'HSDiamhsd894',
#  '黄绍德',
#  '南宁',
#  '2262503019@qq.com',
#  '先生',
#  '',
#  '18',
#  'kunbao7',
#  'cl',
#  '南宁',
#  'kunkunzzzz7@gmail.com',
#  '女士',
#  '',
#  '19',
#  '513572509',
#  'XWJ',
#  '泉州',
#  '513572509@qq.com',
#  '先生',
#  '',
#  '20',
#  'alice7706',
#  '郑凤兰',
#  '厦门',
#  '454447709@qq.com',
#  '女士',
#  '',
#  '21',
#  'YenKang',
#  '顏慷',
#  '台灣-台南',
#  'rcd1988715@gmail.com',
#  '先生',
#  '',
#  '22',
#  'Penny0222',
#  '张盼',
#  '武汉',
#  'zp1992ai@gmail.com',
#  '女士',
#  '',
#  '23',
#  'mental-rotation',
#  '孙蕾',
#  '徐州',
#  'Sam.d.112@icloud.com',
#  '女士',
#  '',
#  '24',
#  'cicei',
#  '曾柯',
#  '长沙',
#  'cicei131@qq.com',
#  '女士',
#  '',
#  '25',
#  'stuian',
#  '蒋文君',
#  '秦皇岛',
#  '892545949@qq.com',
#  '女士',
#  '']

# %%
ls.index('1'), ls.index('30')
# Out:
# (15, 218)

# %%
ls[15:224]
# Out:
# ['1',
#  'VeronicaBai',
#  '白璐',
#  '北京',
#  'bailu03@meituan.com',
#  '女士',
#  '',
#  '2',
#  'Sean-Lu',
#  '陆扬霄',
#  '北京',
#  'i849355052@gmail.com',
#  '先生',
#  '',
#  '3',
#  'Xenaxxx',
#  '徐迅',
#  '北京',
#  'xuxunxx0129@gmail.com',
#  '女士',
#  '',
#  '4',
#  'WentaoSun',
#  '孙文韬',
#  '北京',
#  'sunwentao0322@163.com',
#  '先生',
#  '',
#  '5',
#  'wangh0117',
#  '汪海',
#  '北京',
#  'wanghai14@mails.tsinghua.edu.cn',
#  '先生',
#  '',
#  '6',
#  'gabriel-guobin',
#  '郭斌',
#  '北京',
#  'Gabriel.guobin@gmail.com',
#  '先生',
#  '',
#  '7',
#  'ZephyrG',
#  '关植方',
#  '北京',
#  'zhifang.guan@foxmail.com',
#  '女士',
#  '',
#  '8',
#  'OMlalala',
#  '王琛',
#  '北京',
#  '422173092@qq.com',
#  '先生',
#  '',
#  '9',
#  'MountainDoor',
#  '王玮楠',
#  '北京',
#  'peterwww6@139.com',
#  '先生',
#  '',
#  '10',
#  'chasejwang',
#  '汪健',
#  '北京',
#  'chase.jwang@outlook.com',
#  '先生',
#  '',
#  '11',
#  '13416136446',
#  '李广鹤',
#  '北京',
#  'liguanghe218317@gmail.com',
#  '女士',
#  '',
#  '12',
#  'hunshiouren',
#  '李欣',
#  '北京',
#  'lixinisme1115@126.com',
#  '女士',
#  '',
#  '13',
#  'NeuroYoung',
#  '陆洋',
#  '北京',
#  'runminlyck@gmail.com',
#  '先生',
#  '',
#  '14',
#  'zhangshiyinrunwithcc',
#  '张诗颖',
#  '北京',
#  '981318360@qq.com',
#  '女士',
#  '',
#  '15',
#  'yuu-',
#  '钟煜',
#  '北京',
#  '654683698@qq.com',
#  '先生',
#  '',
#  '16',
#  'juthy1',
#  '巨晓松',
#  '北京',
#  '110500530j@gamil.com',
#  '先生',
#  '',
#  '17',
#  'Wangjunyu',
#  '王浚宇',
#  '北京',
#  'wjyzc@foxmail.com',
#  '先生',
#  '',
#  '18',
#  'alexhooo',
#  '侯陈昊',
#  '北京',
#  'nyylsd@sina.com',
#  '先生',
#  '',
#  '19',
#  'ternknuth',
#  '杨劲',
#  '北京',
#  'ternknuth@qq.com',
#  '先生',
#  '',
#  '20',
#  'vfrbdxf',
#  '董开欣',
#  '北京',
#  '1807603582@qq.com',
#  '女士',
#  '',
#  '21',
#  'wenyan666',
#  '张文燕',
#  '北京',
#  'wenyan.zhang@foxmail.com',
#  '女士',
#  '',
#  '22',
#  'windflyinglx',
#  '李想',
#  '北京',
#  'lixiang_410@foxmail.com',
#  '女士',
#  '',
#  '23',
#  'Geometary',
#  '牛天晓',
#  '北京',
#  '1801938676@qq.com',
#  '先生',
#  '',
#  '24',
#  'TineeOne',
#  '董琛',
#  '北京',
#  'dongchen2015@gmail.com',
#  '女士',
#  '',
#  '25',
#  'elefnt',
#  '妥彦磊',
#  '北京',
#  'tuoyanlei@hotmail.com',
#  '先生',
#  '',
#  '26',
#  'Henryyichao',
#  '侯逸超',
#  '北京',
#  '543423678@qq.com',
#  '先生',
#  '',
#  '27',
#  'yxlbetty',
#  '袁小丽',
#  '北京',
#  'yxl@wiz.cn',
#  '女士',
#  '',
#  '28',
#  'sunshinecx',
#  '陈鑫',
#  '邯郸、北京',
#  '781460009@qq.com',
#  '先生',
#  '',
#  '29',
#  'Pandacoco',
#  '孙荣玥',
#  '京津、秦皇岛',
#  '674052427@qq.com',
#  '女士',
#  '',
#  '30',
#  'liuxianyun5088',
#  '刘仙芸',
#  '天津（居住地）',
#  'liuxianyun5099@163.com',
#  '女士']

# %%
new_ls = ls[224:]
new_ls.index('1'),new_ls.index('47')
# Out:
# (22, 344)

# %%
new_ls[22:350]
# Out:
# ['1',
#  'Ricardotang',
#  '华翌辰',
#  '杭州',
#  'dakeshuide@gmail.com',
#  '先生',
#  '',
#  '2',
#  'Torrtoy',
#  '鲍海峰',
#  '杭州',
#  '787957300@qq.com',
#  '先生',
#  '',
#  '3',
#  'shippomiru',
#  '胡雅晨',
#  '杭州',
#  '297029445@qq.com',
#  '女士',
#  '',
#  '4',
#  'otomobao',
#  '宝志强',
#  '杭州',
#  '17181708@qq.com',
#  '先生',
#  '',
#  '5',
#  'fandongdong89',
#  '范冬冬',
#  '杭州',
#  '809385567@qq.com',
#  '女士',
#  '',
#  '6',
#  'shereb',
#  '王波',
#  '杭州',
#  'wb123@zju.edu.cn',
#  '先生',
#  '',
#  '7',
#  'tcfh2016',
#  '陈联兵',
#  '杭州',
#  'lianbch@gmail.com',
#  '先生',
#  '',
#  '8',
#  'njlhtianwen',
#  '王天闻',
#  '南京',
#  '392476430@qq.com',
#  '先生',
#  '',
#  '9',
#  'Liumang',
#  '刘佳祯',
#  '南京',
#  '61710284@qq.com',
#  '先生',
#  '',
#  '10',
#  'cenweiwei',
#  '岑微微',
#  '宁波',
#  'cenweiwei@gmail.com',
#  '女士',
#  '',
#  '11',
#  'betterMax',
#  '冯雨田',
#  '宁波',
#  'fyt_311@126.com',
#  '先生',
#  '',
#  '12',
#  'Leohb',
#  '廖鸿博',
#  '上海',
#  'lhb_6031@qq.com',
#  '先生',
#  '',
#  '13',
#  'lborodynamo',
#  '田超',
#  '上海',
#  'ronnie.tian@a-carbon.com',
#  '先生',
#  '',
#  '14',
#  'chousawa',
#  '张爽',
#  '上海',
#  '779583547@qq.com',
#  '女士',
#  '',
#  '15',
#  'chuanwj',
#  '王金川',
#  '上海',
#  'chuanwj@163.com',
#  '先生',
#  '',
#  '16',
#  'leilayanhui',
#  '严蕙',
#  '上海',
#  'leilayanhui@sina.com',
#  '女士',
#  '',
#  '17',
#  'Ming-Ding',
#  '丁明',
#  '上海',
#  'joding0000@hotmail.com',
#  '女士',
#  '',
#  '18',
#  'yanzhiw',
#  '刘和宇',
#  '上海',
#  'yanzhiw@gmail.com',
#  '先生',
#  '',
#  '19',
#  'leiyunhe',
#  '雷云鹤',
#  '上海',
#  'yunhe.lei@gmail.com',
#  '女士',
#  '',
#  '20',
#  'yanli-2016',
#  '严礼',
#  '上海',
#  'yanli201051@163.com',
#  '先生',
#  '',
#  '21',
#  'yiiina',
#  '蒋祎娜',
#  '上海',
#  '524117060@qq.com',
#  '女士',
#  '',
#  '22',
#  'VyGiBe',
#  '王健',
#  '上海',
#  'xxlsyq@foxmail.com',
#  '先生',
#  '',
#  '23',
#  'SecZhujun',
#  '朱俊',
#  '上海',
#  'seczhujun@vip.sina.com',
#  '先生',
#  '',
#  '24',
#  'ken0709',
#  '倪利烽',
#  '上海',
#  '86543332@qq.com',
#  '先生',
#  '',
#  '25',
#  'SophieXS',
#  'SoPhie',
#  '上海',
#  '251578821@qq.com',
#  '女士',
#  '',
#  '26',
#  'francesyh',
#  '方溢涵',
#  '上海',
#  '371467702@qq.com',
#  '女士',
#  '',
#  '27',
#  'goldandelion',
#  'yusi',
#  '上海',
#  '2209007118@qq.com',
#  '女士',
#  '',
#  '28',
#  'elsaxxx',
#  '夏晓宣',
#  '上海',
#  '354401906@qq.com',
#  '女士',
#  '',
#  '29',
#  'xuewenqi',
#  '薛文琦',
#  '上海',
#  'xwqiqiqi@icloud.com',
#  '女士',
#  '',
#  '30',
#  'meepochen',
#  '陈铭',
#  '上海',
#  '87437993@qq.com',
#  '先生',
#  '',
#  '31',
#  'Davidfupenghao',
#  '付鹏昊',
#  '上海',
#  'fupenghao@outlook.com',
#  '先生',
#  '',
#  '32',
#  'txytju',
#  '田兴业',
#  '上海',
#  'xingye_tian@tju.edu.cn',
#  '先生',
#  '',
#  '33',
#  'sophiefschen',
#  '陈芳殊',
#  '上海',
#  'sophiefschen@sina.com',
#  '女士',
#  '',
#  '34',
#  'Lesley19',
#  '张瑞',
#  '上海',
#  'Lesley16@gmail.com',
#  '女士',
#  '',
#  '35',
#  'Yifan127',
#  '张一帆',
#  '上海',
#  'yifan127@gmail.com',
#  '女士',
#  '',
#  '36',
#  'leomax01',
#  'leo',
#  '上海',
#  '15900490940@139.com',
#  '先生',
#  '',
#  '37',
#  'mcbub',
#  '徐蜀辰',
#  '上海',
#  'xushuchen@gmail.com',
#  '先生',
#  '',
#  '38',
#  'yzlovekid',
#  '陆颖之',
#  '上海',
#  'yzlovekid@gmail.com',
#  '女士',
#  '',
#  '39',
#  'Zxlon',
#  '周绪龙',
#  '上海、江浙',
#  'ymeiorg@gmail.com',
#  '先生',
#  '',
#  '40',
#  'JunPi',
#  '皮君',
#  '上海、郑州',
#  'balancepot@gmail.com',
#  '先生',
#  '',
#  '41',
#  'irene6161',
#  '六一（刘怡）',
#  '苏州',
#  '1976046205@qq.com',
#  '女士',
#  '',
#  '42',
#  'Vernunftsoft',
#  '张云帆',
#  '苏州',
#  'vernunft@foxmail.com',
#  '先生',
#  '',
#  '43',
#  'hhxjycl',
#  '袁长亮',
#  '苏州',
#  '41022614@qq.com',
#  '先生',
#  '',
#  '44',
#  'JonasCynical',
#  '赵健',
#  '苏州、徐州',
#  'JonasCynical@hotmail.com',
#  '先生',
#  '',
#  '45',
#  'CallingCrab',
#  '何惜露',
#  '温州',
#  '23645508@qq.com',
#  '女士',
#  '',
#  '46',
#  'draachen',
#  '李小龙',
#  '无锡',
#  'brucelxl@qq.com',
#  '先生',
#  '',
#  '47',
#  'starsCX',
#  '成星',
#  '无锡',
#  'starscx@qq.com',
#  '先生']

# %%
VALUE = [('1','30'),('1','47'),('1','26'),('1','25')]
AREA = ['BEIJING','CHANG','ZHU','OTHER']
stu_list = {}
i = 0
j = len(ls)-1
t = 0
for (start,end) in VALUE:
    m = ls.index(start, i, j)
    n = ls.index(end, i, j)
    
    i = n + 6
    stu_list[AREA[t]] = ls[m:i]
    t = t + 1

#print(stu_list)

# %%
github_user = []
for area in AREA:
    length = len(stu_list[area])
    for i in range(1,length,7):
        github_user.append(stu_list[area][i])
print(github_user)
# Out:
# ['VeronicaBai', 'Sean-Lu', 'Xenaxxx', 'WentaoSun', 'wangh0117', 'gabriel-guobin', 'ZephyrG', 'OMlalala', 'MountainDoor', 'chasejwang', '13416136446', 'hunshiouren', 'NeuroYoung', 'zhangshiyinrunwithcc', 'yuu-', 'juthy1', 'Wangjunyu', 'alexhooo', 'ternknuth', 'vfrbdxf', 'wenyan666', 'windflyinglx', 'Geometary', 'TineeOne', 'elefnt', 'Henryyichao', 'yxlbetty', 'sunshinecx', 'Pandacoco', 'liuxianyun5088', 'Ricardotang', 'Torrtoy', 'shippomiru', 'otomobao', 'fandongdong89', 'shereb', 'tcfh2016', 'njlhtianwen', 'Liumang', 'cenweiwei', 'betterMax', 'Leohb', 'lborodynamo', 'chousawa', 'chuanwj', 'leilayanhui', 'Ming-Ding', 'yanzhiw', 'leiyunhe', 'yanli-2016', 'yiiina', 'VyGiBe', 'SecZhujun', 'ken0709', 'SophieXS', 'francesyh', 'goldandelion', 'elsaxxx', 'xuewenqi', 'meepochen', 'Davidfupenghao', 'txytju', 'sophiefschen', 'Lesley19', 'Yifan127', 'leomax01', 'mcbub', 'yzlovekid', 'Zxlon', 'JunPi', 'irene6161', 'Vernunftsoft', 'hhxjycl', 'JonasCynical', 'CallingCrab', 'draachen', 'starsCX', 'lsl1415', 'Twanjun', 'HerbertAChen', 'CarefreeLee', 'sardine2', 'tyfff', '17days', 'simpleowen', 'gzMichael', 'ceciliacheng', 'shi1234', 'guoyuming', 'EattheSun', 'linfeng365', 'HenryLGL', 'derek-cheng', 'dersonnex', 'panfeng3141', 'gogu', 'lying87', 'summerpenguin', 'mxclover', 'Tina-Tiian', 'Tracy-CUHK', 'LiuArthur', 'scratlzj', 'tamuleifan', 'BravoCiao', 'aciie', 'hstaoqian', 'YCR007', 'vanxv', 'xbaiyuan', 'NBR-hugh', 'fatfox2016', 'code661', 'luckysilly', 'MagicCheng', 'hwast', 'serenechen', 'stonemask', 'livingworld', 'HSDiamhsd894', 'kunbao7', '513572509', 'alice7706', 'YenKang', 'Penny0222', 'mental-rotation', 'cicei', 'stuian']

# %%
print(len(github_user))
# Out:
# 128

# %%
len(stu_list['BEIJING'])
# Out:
# 209

# %%
print(stu_list['CHANG'])
# Out:
# ['1', 'Ricardotang', '华翌辰', '杭州', 'dakeshuide@gmail.com', '先生', '', '2', 'Torrtoy', '鲍海峰', '杭州', '787957300@qq.com', '先生', '', '3', 'shippomiru', '胡雅晨', '杭州', '297029445@qq.com', '女士', '', '4', 'otomobao', '宝志强', '杭州', '17181708@qq.com', '先生', '', '5', 'fandongdong89', '范冬冬', '杭州', '809385567@qq.com', '女士', '', '6', 'shereb', '王波', '杭州', 'wb123@zju.edu.cn', '先生', '', '7', 'tcfh2016', '陈联兵', '杭州', 'lianbch@gmail.com', '先生', '', '8', 'njlhtianwen', '王天闻', '南京', '392476430@qq.com', '先生', '', '9', 'Liumang', '刘佳祯', '南京', '61710284@qq.com', '先生', '', '10', 'cenweiwei', '岑微微', '宁波', 'cenweiwei@gmail.com', '女士', '', '11', 'betterMax', '冯雨田', '宁波', 'fyt_311@126.com', '先生', '', '12', 'Leohb', '廖鸿博', '上海', 'lhb_6031@qq.com', '先生', '', '13', 'lborodynamo', '田超', '上海', 'ronnie.tian@a-carbon.com', '先生', '', '14', 'chousawa', '张爽', '上海', '779583547@qq.com', '女士', '', '15', 'chuanwj', '王金川', '上海', 'chuanwj@163.com', '先生', '', '16', 'leilayanhui', '严蕙', '上海', 'leilayanhui@sina.com', '女士', '', '17', 'Ming-Ding', '丁明', '上海', 'joding0000@hotmail.com', '女士', '', '18', 'yanzhiw', '刘和宇', '上海', 'yanzhiw@gmail.com', '先生', '', '19', 'leiyunhe', '雷云鹤', '上海', 'yunhe.lei@gmail.com', '女士', '', '20', 'yanli-2016', '严礼', '上海', 'yanli201051@163.com', '先生', '', '21', 'yiiina', '蒋祎娜', '上海', '524117060@qq.com', '女士', '', '22', 'VyGiBe', '王健', '上海', 'xxlsyq@foxmail.com', '先生', '', '23', 'SecZhujun', '朱俊', '上海', 'seczhujun@vip.sina.com', '先生', '', '24', 'ken0709', '倪利烽', '上海', '86543332@qq.com', '先生', '', '25', 'SophieXS', 'SoPhie', '上海', '251578821@qq.com', '女士', '', '26', 'francesyh', '方溢涵', '上海', '371467702@qq.com', '女士', '', '27', 'goldandelion', 'yusi', '上海', '2209007118@qq.com', '女士', '', '28', 'elsaxxx', '夏晓宣', '上海', '354401906@qq.com', '女士', '', '29', 'xuewenqi', '薛文琦', '上海', 'xwqiqiqi@icloud.com', '女士', '', '30', 'meepochen', '陈铭', '上海', '87437993@qq.com', '先生', '', '31', 'Davidfupenghao', '付鹏昊', '上海', 'fupenghao@outlook.com', '先生', '', '32', 'txytju', '田兴业', '上海', 'xingye_tian@tju.edu.cn', '先生', '', '33', 'sophiefschen', '陈芳殊', '上海', 'sophiefschen@sina.com', '女士', '', '34', 'Lesley19', '张瑞', '上海', 'Lesley16@gmail.com', '女士', '', '35', 'Yifan127', '张一帆', '上海', 'yifan127@gmail.com', '女士', '', '36', 'leomax01', 'leo', '上海', '15900490940@139.com', '先生', '', '37', 'mcbub', '徐蜀辰', '上海', 'xushuchen@gmail.com', '先生', '', '38', 'yzlovekid', '陆颖之', '上海', 'yzlovekid@gmail.com', '女士', '', '39', 'Zxlon', '周绪龙', '上海、江浙', 'ymeiorg@gmail.com', '先生', '', '40', 'JunPi', '皮君', '上海、郑州', 'balancepot@gmail.com', '先生', '', '41', 'irene6161', '六一（刘怡）', '苏州', '1976046205@qq.com', '女士', '', '42', 'Vernunftsoft', '张云帆', '苏州', 'vernunft@foxmail.com', '先生', '', '43', 'hhxjycl', '袁长亮', '苏州', '41022614@qq.com', '先生', '', '44', 'JonasCynical', '赵健', '苏州、徐州', 'JonasCynical@hotmail.com', '先生', '', '45', 'CallingCrab', '何惜露', '温州', '23645508@qq.com', '女士', '', '46', 'draachen', '李小龙', '无锡', 'brucelxl@qq.com', '先生', '', '47', 'starsCX', '成星', '无锡', 'starscx@qq.com', '先生']

# %%
print(stu_list['ZHU'])
# Out:
# ['1', 'lsl1415', '卢舜龙', '汕头', 'stlsl@outlook.com', '先生', '', '2', 'Twanjun', '汤婉君', '汕头', '847647495@qq.com', '女士', '', '3', 'HerbertAChen', '陈光前', '佛山', 'u8800cgq@gmail.com', '先生', '', '4', 'CarefreeLee', '李得阳', '惠州', '327403606@qq.com', '先生', '', '5', 'sardine2', '莫欣妮', '广州', 'sardine2@gmail.com', '女士', '', '6', 'tyfff', '谭永菲', '广州', 'tyf6918@qq.com', '女士', '', '7', '17days', '刘华龙', '广州', 'noyliu@qq.com', '先生', '', '8', 'simpleowen', '黄文', '广州', 'deardamao@gmail.com', '先生', '', '9', 'gzMichael', '陈宁', '广州', '1960809@qq.com', '先生', '', '10', 'ceciliacheng', '程晓琳', '广州', '1772979678@qq.com', '女士', '', '11', 'shi1234', '罗坚实', '广州', 'ljshi123@foxmail.com', '先生', '', '12', 'guoyuming', '郭雨明', '广州', '410545341@qq.com', '先生', '', '13', 'EattheSun', '张昀', '广州，深圳', 'eatthesun0319@gmail.com', '女士', '', '14', 'linfeng365', '林峰', '广州、深圳、中山', 'linfeng82@qq.com', '先生', '', '15', 'HenryLGL', '陆国亮', '广州、清远', '945353116@qq.com', '先生', '', '16', 'derek-cheng', 'derek', '广州、北京', 'derek@viewteam.cn', '先生', '', '17', 'dersonnex', '许晨风', '深圳', 'dersonnex@outlook.com', '女士', '', '18', 'panfeng3141', '徐攀峰', '深圳', '1131308065@qq.com', '女士', '', '19', 'gogu', '王重阳', '深圳', 'Gogu9909@gmail.com', '先生', '', '20', 'lying87', '罗颖', '深圳', '604065312@qq.com', '女士', '', '21', 'summerpenguin', '赵子涵', '深圳', 'zhzhzo@hotmail.com', '女士', '', '22', 'mxclover', '明星', '深圳', 'mingx.py@qq.com', '先生', '', '23', 'Tina-Tiian', '田苗', '中山', '380626617@qq.com', '女士', '', '24', 'Tracy-CUHK', '李如', '深圳', 'lirutracy@hotmail.com', '女士', '', '25', 'LiuArthur', '刘时元', '深圳', '771604530@qq.com', '先生', '', '26', 'scratlzj', '刘正杰', '深圳', 'scratlzj@gmail.com', '先生']

# %%
print(stu_list['OTHER'])
# Out:
# ['1', 'tamuleifan', '樊磊', '北京、休斯顿', 'heufanlei@gmail.com', '先生', '', '2', 'BravoCiao', '曹欢', '伯明翰、南京、上海', 'cieloc@sina.com', '女士', '', '3', 'aciie', '刘清玉', '成都', '423780823@qq.com', '女士', '', '4', 'hstaoqian', '陶迁', '成都', 'hstaoqian@me.com', '先生', '', '5', 'YCR007', '袁春蓉', '成都', '2199553410@qq.com', '女士', '', '6', 'vanxv', '许从从', '成都、上海', 'ironvanxv@gmail.com', '先生', '', '7', 'xbaiyuan', '柳白猿', '福冈', 'soulfighter163@gmail.com', '先生', '', '8', 'NBR-hugh', '倪必荣', '福州、 武汉', '574168029@qq.com', '先生', '', '9', 'fatfox2016', '武黎', '阜阳', '15345586621@189.cn', '先生', '', '10', 'code661', '谭笃志', '湖南株洲', 'tan_661@icloud.com', '先生', '', '11', 'luckysilly', '孙祎', '济南', '894779586@qq.com', '女士', '', '12', 'MagicCheng', '于耀程', '辽阳', '569326782@qq.com', '先生', '', '13', 'hwast', '刘懿遥', '洛杉矶', 'elle95@qq.com', '女士', '', '14', 'serenechen', 'Serene Chen', '密西沙加，多伦多', 'seeyu.chen@gmail.com', '女士', '', '15', 'stonemask', '王琦', '南昌、厦门', 'stonemask@foxmail.com', '先生', '', '16', 'livingworld', '赖河涛', '南宁', '455412741@qq.com', '先生', '', '17', 'HSDiamhsd894', '黄绍德', '南宁', '2262503019@qq.com', '先生', '', '18', 'kunbao7', 'cl', '南宁', 'kunkunzzzz7@gmail.com', '女士', '', '19', '513572509', 'XWJ', '泉州', '513572509@qq.com', '先生', '', '20', 'alice7706', '郑凤兰', '厦门', '454447709@qq.com', '女士', '', '21', 'YenKang', '顏慷', '台灣-台南', 'rcd1988715@gmail.com', '先生', '', '22', 'Penny0222', '张盼', '武汉', 'zp1992ai@gmail.com', '女士', '', '23', 'mental-rotation', '孙蕾', '徐州', 'Sam.d.112@icloud.com', '女士', '', '24', 'cicei', '曾柯', '长沙', 'cicei131@qq.com', '女士', '', '25', 'stuian', '蒋文君', '秦皇岛', '892545949@qq.com', '女士']
