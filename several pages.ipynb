# %%
import json
import requests

USERNAME = 'leiyunhe'
PASSWORD = 'Craney20150421'

REPO_OWNER = 'AIMinder'
REPO_NAME = 'Py103'

LABEL = 'task'
STATE = 'all'

TIME = '2017-01-01T00:00:00Z'
payload1 = {'state':STATE,
            'since':TIME}
def list_task_issue_number():
    url = 'https://api.github.com/repos/%s/%s/issues' % (REPO_OWNER, REPO_NAME)
    #url = 'https://api.github.com/orgs/%s/issues' % (ORG_NAME)
    s = requests.session()
    s.auth = (USERNAME,PASSWORD)
    r = s.get(url,params = payload1)
    print(r.headers)
    m = r.headers
    print(r.headers["Link"])
    
    result = json.loads(r.text)
    #print(result)
    ls = []
    for x in result:
        m = [x["url"],x["number"]]
        ls.append(m)
    return ls

r = list_task_issue_number()
print(len(r))
# Out:
# {'Server': 'GitHub.com', 'Date': 'Tue, 14 Mar 2017 13:38:09 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Status': '200 OK', 'X-RateLimit-Limit': '5000', 'X-RateLimit-Remaining': '4995', 'X-RateLimit-Reset': '1489501753', 'Cache-Control': 'private, max-age=60, s-maxage=60', 'Vary': 'Accept, Authorization, Cookie, X-GitHub-OTP, Accept-Encoding', 'ETag': 'W/"a34a38830c68c81cba7e36263c639b89"', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/repositories/76613629/issues?state=all&since=2017-01-01T00%3A00%3A00Z&page=2>; rel="next", <https://api.github.com/repositories/76613629/issues?state=all&since=2017-01-01T00%3A00%3A00Z&page=10>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval', 'Access-Control-Allow-Origin': '*', 'Content-Security-Policy': "default-src 'none'", 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'deny', 'X-XSS-Protection': '1; mode=block', 'X-Served-By': 'a51acaae89a7607fd7ee967627be18e4', 'Content-Encoding': 'gzip', 'X-GitHub-Request-Id': 'E087:6D3A:80C0491:A36A227:58C7F240'}
# <https://api.github.com/repositories/76613629/issues?state=all&since=2017-01-01T00%3A00%3A00Z&page=2>; rel="next", <https://api.github.com/repositories/76613629/issues?state=all&since=2017-01-01T00%3A00%3A00Z&page=10>; rel="last"
# 30

# %%
s = "<http:skdfjasld>;rel="next",<dthkl>;rel="last""

# %%
s[1:-1]
# Out:
# 'http:skdfjasld'

# %%
s.split()
# Out:
# ['<http:skdfjasld>']

# %%
d = '''<https://api.github.com/repositories/76613629/issues?state=all&since=2017-01-01T00%3A00%3A00Z&page=2>; rel="next", <https://api.github.com/repositories/76613629/issues?state=all&since=2017-01-01T00%3A00%3A00Z&page=10>; rel="last"'''

# %%
import json
import requests

USERNAME = 'leiyunhe'
PASSWORD = 'Craney20150421'

REPO_OWNER = 'AIMinder'
REPO_NAME = 'Py103'

LABEL = 'task'
STATE = 'all'

TIME = '2017-01-01T00:00:00Z'
payload1 = {'state':STATE,
            'since':TIME}
url_list = []
def list_task_issue_number():
    url = 'https://api.github.com/repos/%s/%s/issues' % (REPO_OWNER, REPO_NAME)
    #url = 'https://api.github.com/orgs/%s/issues' % (ORG_NAME)
    s = requests.session()
    s.auth = (USERNAME,PASSWORD)
    r = s.get(url,params = payload1)
#     print(r.headers)
    li = r.headers["Link"]
    next_url=li[(li.index("<") + 1):li.index(">")]
    url_list.append(next_url)
    
    result = json.loads(r.text)
    #print(result)
    ls = []
    for x in result:
        m = [x["url"],x["number"]]
        ls.append(m)
    return ls

r = list_task_issue_number()
print(len(r))
print(url_list)
# Out:
# 30
# ['https://api.github.com/repositories/76613629/issues?state=all&since=2017-01-01T00%3A00%3A00Z&page=2']

# %%
import json
import requests

USERNAME = 'leiyunhe'
PASSWORD = 'Craney20150421'

REPO_OWNER = 'AIMinder'
REPO_NAME = 'Py103'

LABEL = 'task'
STATE = 'all'

TIME = '2017-01-01T00:00:00Z'
payload1 = {'state':STATE,
            'since':TIME}

def traverse_pages():
    '''travesing all pages, return a list including all pages'''
    url = 'https://api.github.com/repos/%s/%s/issues' % (REPO_OWNER, REPO_NAME)
    #url = 'https://api.github.com/orgs/%s/issues' % (ORG_NAME)
    s = requests.session()
    s.auth = (USERNAME,PASSWORD)
    r = s.get(url,params = payload1)
    li = r.headers["Link"]
    next_url=li[(li.index("<") + 1):li.index(">")]
    result = json.loads(r.text)
    ls = []
    ls.append(result)      
    while True:
        r = s.get(next_url,params = payload1)
        result = json.loads(r.text)
        ls.append(result)
        link = r.headers['Link']
        if 'next' not in link:
            break
        next_url=link[(link.index("<") + 1):link.index(">")]
    return ls
           
# print(traverse_pages())
# Out:
# [[{'url': 'https://api.github.com/repos/AIMinder/Py103/issues/289', 'repository_url': 'https://api.github.com/repos/AIMinder/Py103', 'labels_url': 'https://api.github.com/repos/AIMinder/Py103/issues/289/labels{/name}', 'comments_url': 'https://api.github.com/repos/AIMinder/Py103/issues/289/comments', 'events_url': 'https://api.github.com/repos/AIMinder/Py103/issues/289/events', 'html_url': 'https://github.com/AIMinder/Py103/issues/289', 'id': 214249386, 'number': 289, 'title': '【帮看】工作来找我项目，技术实现，有无其他更好的实现方法？', 'user': {'login': '13416136446', 'id': 20377303, 'avatar_url': 'https://avatars2.githubusercontent.com/u/20377303?v=3', 'gravatar_id': '', 'url': 'https://api.github.com/users/13416136446', 'html_url': 'https://github.com/13416136446', 'followers_url': 'https://api.github.com/users/13416136446/followers', 'following_url': 'https://api.github.com/users/13416136446/following{/other_user}', 'gists_url': 'https://api.github.com/users/13416136446/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/13416136446/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/13416136446/subscriptions', 'organizations_url': 'https://api.github.com/users/13416136446/orgs', 'repos_url': 'https://api.github.com/users/13416136446/repos', 'events_url': 'https://api.github.com/users/13416136446/events{/privacy}', 'received_events_url': 'https://api.github.com/users/13416136446/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 501751343, 'url': 'https://api.github.com/repos/AIMinder/Py103/labels/question', 'name': 'question', 'color': 'cc317c', 'default': True}], 'state': 'open', 'locked': False, 'assignee': {'login': '13416136446', 'id': 20377303, 'avatar_url': 'https://avatars2.githubusercontent.com/u/20377303?v=3', 'gravatar_id': '', 'url': 'https://api.github.com/users/13416136446', 'html_url': 'https://github.com/13416136446', 'followers_url': 'https://api.github.com/users/13416136446/followers', 'following_url': 'https://api.github.com/users/13416136446/following{/other_user}', 'gists_url': 'https://api.github.com/users/13416136446/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/13416136446/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/13416136446/subscriptions', 'organizations_url': 'https://api.github.com/users/13416136446/orgs', 'repos_url': 'https://api.github.com/users/13416136446/repos', 'events_url': 'https://api.github.com/users/13416136446/events{/privacy}', 'received_events_url': 'https://api.github.com/users/13416136446/received_events', 'type': 'User', 'site_admin': False}, 'assignees': [{'login': '13416136446', 'id': 20377303, 'avatar_url': 'https://avatars2.githubusercontent.com/u/20377303?v=3', 'gravatar_id': '', 'url': 'https://api.github.com/users/13416136446', 'html_url': 'https://github.com/13416136446', 'followers_url': 'https://api.github.com/users/13416136446/followers', 'following_url': 'https://api.github.com/users/13416136446/following{/other_user}', 'gists_url': 'https://api.github.com/users/13416136446/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/13416136446/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/13416136446/subscriptions', 'organizations_url': 'https://api.github.com/users/13416136446/orgs', 'repos_url': 'https://api.github.com/users/13416136446/repos', 'events_url': 'https://api.github.com/users/13416136446/events{/privacy}', 'received_events_url': 'https://api.github.com/users/13416136446/received_events', 'type': 'User', 'site_admin': False}], 'milestone': None, 'comments': 1, 'created_at': '2017-03-15T00:41:25Z', 'updated_at': '2017-03-15T09:06:07Z', 'closed_at': None, 'body': '- 需求场景：在天维网的招聘版块抓取职位信息及邮箱，自动发送求职邮件，筛选返回邮件并备注回件人提供的是什么职位。\r\n\r\n- 经初步搜索后认为需要的技术为：\r\n1、定向抓取：用beautifulsoup解析。学会这个，可以在以后任意抓取定向网页的内容。\r\n\r\n2、python自动撰写发送邮箱，stmp import email 功能。自动撰写和发送邮件是程序员必备技能。\r\n\r\n3、list变dict，咱们课程作业就是这个，当做复习。\r\n\r\n4、此外的其他功能，gmail自带。\r\n\r\n- 项目的具体需求及项目实现步骤和技 ...

# %%
def get_all_issues():
    ls = traverse_pages()
    issue_ls = []
    for page in ls:
        for x in page:
            m = [x["title"],x["number"]]
            issue_ls.append(m)
    return issue_ls
# print(get_all_issues())
# Out:
# [['【帮看】工作来找我项目，技术实现，有无其他更好的实现方法？', 289], ['未参与结业组队的你，还可以做这些事 ；）', 288], ['复盘一下，分享你参加 Py103 课程的变化/感受/心得/收获 吧！', 287], ['结业路演即将开始，来分享你的经验，或聊聊你的困扰吧！', 286], ['[10w] 来此更新你的结业项目进展', 285], ['反醉点 打油诗', 284], ['快将你的教练加到结业项目 IM 群中！', 283], ['nohup命令运行程序后微信公众号不能查询', 282], ['问题：我的gitbook的summary目录文件设置出错', 281], ['chap7 实现微信公众号的文本消息POST响应为空。', 280], ['Ch7 Py103微信群答疑（阿里云、有道云、SAE部署坑总结）', 279], ['[9wd6] 是也乎，本周六，来和大妈聊聊你的困惑 ;-)', 278], ['[9w] 来此更新你的结业项目进展', 277], ['【求助】ch4 page not found', 276], ['如何用 Flask-SQLAlchemy 按行或按列批量查询数据，并生成 html table？', 275], ['利用爬虫获取留学大数据（希望得到教练们关于项目可行性的建议）', 274], ['SAE应用部署，遇到Server aborted the SSL handshake', 273], ['daocloud 部署 Container start failed', 272], ['chap6作业，使用 pip install -r requirements.txt安装文件不成功', 271], ['如何顺畅协同开发？一起来分享你的经验吧！', 270], ['[8w]ZoomQuiet本周微信群专题回答', 269], ['时间管理项目队员征集', 268], ['欢迎在此分享你遇到的 ch7 优秀实践', 267], ['其他地区 ch7 任务提交处', 266], ['珠三角大区 ch7 任务提交处', 265], ['长三角大区 ch7 任务提交处', 264], ['北京大区 ch7 任务提交处', 263], ['如果你还没确定结业项目团队，快来这里报个到~', 262], ['求助：无法push。提示Permission denied (publickey). fatal: Could not read from remote repository.', 261], ['问题：因为buildpack被heroku拒绝，无法push的问题', 260], ['KOL数据库 - 项目成员召集', 259], [' “我的档案”——新浪微博个人文本抓取项目队员征集', 258], ['问题：在heroku上关联自己在github上的仓库失败', 257], ['ch3【求助】用sys,json,request写代码，在终端运行时没有返回API数据，大概是哪里出了问题？', 256], ['来来来~ 私人订制 | “家庭”主题应用项目 队员征集', 255], ['为什么程序员是倒过来写代码的？', 254], ['pyenv virtualenv 关闭之后，忘记了文件夹用户名称，怎么办', 253], ['结业项目”TagaDay“ 招募队友+讨论', 252], ['安装PEM server过程中，出现提示：server does not support ssl but ssl was required', 251], ['欢迎在此分享你遇到的 ch6 优秀实践', 250], ['其他地区 ch6 任务提交处', 249], ['珠三角大区 ch6 任务提交处', 248], ['长三角大区 ch6 任务提交处', 247], ['北京大区 ch6 任务提交处', 246], ['结业项目《情感指数引导的证券分析投资》 招募队友', 245], ['结业项目「神奇公式筛股器」开组啦，诚邀你的加盟', 244], ['实现真实世界可用的 MVP | Ch3 绿色通道', 243], ['搞定「输入-处理-输出」MVP | Ch1 绿色通道', 242], ['“安然旅行”项目队员征集', 241], ['如何使用SQLAlchemy将获取的天气数据插入储存到数据库？', 240], ['广州线下meetup报名（20170219）', 239], ['如何实现多线程调用数据库', 238], ['北京大区线下活动报名/纪要（每周更新）', 237], ['詢問mySQL & python安裝問題', 236], ['（更新报错信息的简单解决方法和当前的代码仓库）求问报错信息“SQLite objects created in a thread can only be used in that same thread”的含意？', 235], ['欢迎在此分享你遇到的 ch5 优秀实践', 234], ['其他地区 ch5 任务提交处', 233], ['珠三角大区 ch5 任务提交处', 232], ['长三角大区 ch5 任务提交处', 231], ['北京大区 ch5 任务提交处', 230], ['if...elif 结构无法实现不同按钮的不同功能', 229], ['【Help！】Flask、API、HTML文件全有了，但是报错view function did not return a response', 228], ['没完成4w，进了django坑。', 227], ['使用flask-SQLAlchemy创建数据库，插入一条数据记录失败。', 226], ['求助：如何将html页面的button的点击触发python函数', 225], ['幼儿社交 项目队员征集', 224], ['【ch4微信答疑记录】', 223], ['【ch4微信群答疑提问】为什么使用app = Flask(__name__)却认证不了？', 222], ['组建战队，完成结业项目吧！', 221], ['服务器接收不到输入的城市信息', 220], ['设置两个同路径函数会发生什么？', 219], ['【求助】在哪里可以看到API的URL和帮助文档？', 218], ['欢迎在此分享你遇到的 ch4 优秀实践 ', 217], ['其他大区 ch4 任务提交处', 216], ['珠三角大区 ch4 任务提交处', 215], ['长三角大区 ch4 任务提交处', 214], ['北京大区 ch4 任务提交处', 213], ['Geometary完成ch2任务啦 | 北京大区', 212], ['hsdiamhsd894终于完成ch3作业', 211], ["问题：requests模块已经装好了，报错显示'requests' has no attribute 'get'", 210], ['无法设置微信公众号的消息接收服务器URL', 209], ['Mac OS X 10.12下搭建Python3.6 + PyQt5.8.0 +Eric6开发中的问题', 208], ['张昀完成 ch0 任务啦 | 深圳大区', 207], ['[问题] 如何将「卡片大法」用在 Python 课中？', 206], ['为什么 开智编程思维课选 Python 入门 而非 其他？', 205], ['为什么 开智编程思维课选 Python 入门 而非 其他？', 204], ['常用 API 集市', 203], ['【问题】PYTHON脚本直解练习：最后一行报错，无法运行，找不到原因', 202], ['问题：PyQt5中，调用QGuiApplication出现错误：Cannot create a QWidget without QApplication', 201], ['欢迎在此分享你遇到的 ch3 优秀实践', 200], ['其他地区 ch3 任务提交处', 199], ['珠三角大区 ch3 任务提交处', 198], ['长三角大区 ch3 任务提交处', 197], ['北京大区 ch3 任务提交处', 196], ['如何用Disqus给Gitbook添加评论功能？（已解决）', 195], ['【求助】ch2：调用tkinter时， 命令行总是报错，问题出在哪里？', 194], ['求助ch2任务运行程序无报错，但是没有tk窗口出现', 193], ['求助！get()无法获得entry部分输入的城市名（问题已解决）', 192], ['如何让控件在窗口下方右侧横排', 191], ['安装新tkinter后，Mac下GUI窗口仍不能输入中文', 190], ['Ch2_Text Widget_Should I use pillow wheels to build text widget on Mac?[help wanted]', 189], ['求助 安装cmder后用git命令时无法输入用户密码', 188], ['把指令放在了函数里', 187], ['Ch2_Modules and Classes_Why my modules does not run after I define the function?【help wanted】', 186], ['其他地区 ch2 任务提交处', 185], ['珠三角大区 ch2 任务提交处', 184], [' ...

# %%
issues = [['任务提交处', 3],['长三角大区ch1任务提交处', 3]]
def get_issue_number(area, issue):
    issue_number = {'ch1':None, 'ch2': None, 'ch3': None, 'ch4': None, 'ch5': None, 'ch6': None, 'ch7': None}
    for chapter in issue_number.keys():
        if area in issue[0] and chapter in issue[0]:
            issue_number[chapter] = issue[1]
    return issue_number

# %%
AREA = {'长三角大区','北京大区','其他地区'}
for area in AREA:
    for issue in issues:
        r = get_issue_number(area, issue)
        print(r)
# Out:
# {'ch1': None, 'ch2': None, 'ch3': None, 'ch4': None, 'ch5': None, 'ch6': None, 'ch7': None}
# {'ch1': 3, 'ch2': None, 'ch3': None, 'ch4': None, 'ch5': None, 'ch6': None, 'ch7': None}
# {'ch1': None, 'ch2': None, 'ch3': None, 'ch4': None, 'ch5': None, 'ch6': None, 'ch7': None}
# {'ch1': None, 'ch2': None, 'ch3': None, 'ch4': None, 'ch5': None, 'ch6': None, 'ch7': None}
# {'ch1': None, 'ch2': None, 'ch3': None, 'ch4': None, 'ch5': None, 'ch6': None, 'ch7': None}
# {'ch1': None, 'ch2': None, 'ch3': None, 'ch4': None, 'ch5': None, 'ch6': None, 'ch7': None}

# %%
issues = [['任务提交处', 3],['长三角大区ch1任务提交处', 3]]
AREA = {'长三角大区','北京大区','其他地区'}
def get_issue_number(area, issues):
    issue_number = {'ch1':None, 'ch2': None, 'ch3': None, 'ch4': None, 'ch5': None, 'ch6': None, 'ch7': None}
    for issue in issues:
        for chapter in issue_number.keys():
            if area in issue[0] and chapter in issue[0]:
                issue_number[chapter] = issue[1]
    return issue_number
for area in AREA:
    r = get_issue_number(area, issues)
    print(r)
# Out:
# {'ch1': 3, 'ch2': None, 'ch3': None, 'ch4': None, 'ch5': None, 'ch6': None, 'ch7': None}
# {'ch1': None, 'ch2': None, 'ch3': None, 'ch4': None, 'ch5': None, 'ch6': None, 'ch7': None}
# {'ch1': None, 'ch2': None, 'ch3': None, 'ch4': None, 'ch5': None, 'ch6': None, 'ch7': None}

# %%
issue_number = {'ch1':None, 'ch2': None, 'ch3': None, 'ch4': None, 'ch5': None, 'ch6': None, 'ch7': None}
issue_number.keys()
# Out:
# dict_keys(['ch1', 'ch2', 'ch3', 'ch4', 'ch5', 'ch6', 'ch7'])

# %%
#遍历所有
for issue in issue_ls:
    for issue_num in issue[1]:
        ISSUE_NUMBER = issue_num

# %%
import json
import requests

USERNAME = 'leiyunhe'
PASSWORD = 'Craney20150421'

REPO_OWNER = 'AIMinder'
REPO_NAME = 'Py103'

LABEL = 'task'
STATE = 'all'

TIME = '2017-01-01T00:00:00Z'
payload2 = {'state':STATE,
            'since':TIME}
def submit_task_issue(ISSUE_NUMBER):
    '''
    List comments on an issue
    return: user_name, comments_url, created_at_time
    DOC  https://developer.github.com/v3/issues/comments/
    '''
    url = 'https://api.github.com/repos/%s/%s/issues/%s/comments' % (REPO_OWNER, REPO_NAME,ISSUE_NUMBER)
    s = requests.session()
    s.auth = (USERNAME,PASSWORD)
    r = s.get(url,params = payload2)
    result = json.loads(r.text)
    # print(result)
    ls = []
    for x in result:
#         print(x)
    # m = [x["url"],x["created_at"],x["user"]]
        m = [x["url"],x["created_at"],x["user"]["login"]]
    # m = (x["user"]["login"],x["created_at"])
#         print(m)
        ls.append(m)
    return ls
#     print(ls)

# submit_task_issue('264')
d = {'ch1':3,"ch2":4,"ch3":5,"ch4":8,"ch5":9,"ch6":10,"ch7":45}
for ch_num in d.keys():
    issue_num = d[ch_num]
    print(issue_num)
    comments =  submit_task_issue(issue_num)
    print(comments)

    

# ls_area_issue_numbers = get_submit_time.get_issue_number(area, ls_issues)
# 			# print(ls_area_issue_numbers)
# 		for  ch_num  in ls_area_issue_numbers.keys():
# 			issue_num = ls_area_issue_numbers[ch_num]
# 			print(issue_num)
# 			# print('issue_num: %s, issue_num: %r' % (type(issue_num), issue_num))
# 			comments =  get_submit_time.submit_task_issue(issue_num)
# Out:
# 3
# [['https://api.github.com/repos/AIMinder/Py103/issues/comments/269847399', '2016-12-31T03:48:00Z', 'txytju'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269855411', '2016-12-31T08:24:33Z', 'CallingCrab'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269890017', '2017-01-01T02:31:52Z', 'lborodynamo'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269890242', '2017-01-01T02:44:10Z', 'yiiina'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269893912', '2017-01-01T06:44:28Z', 'JonasCynical'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269894415', '2017-01-01T07:15:30Z', 'chousawa'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269897772', '2017-01-01T10:08:58Z', 'draachen'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269899839', '2017-01-01T11:38:07Z', 'Liumang'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269902745', '2017-01-01T13:19:36Z', 'betterMax'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269903841', '2017-01-01T13:54:26Z', 'francesyh'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269904115', '2017-01-01T14:02:28Z', 'VyGiBe'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269905947', '2017-01-01T14:56:06Z', 'vanxv'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269908218', '2017-01-01T15:58:03Z', 'otomobao'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269954203', '2017-01-02T10:21:59Z', 'Davidfupenghao'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269971408', '2017-01-02T13:18:20Z', 'JunPi'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270037490', '2017-01-03T00:49:59Z', 'Ming-Ding'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270049377', '2017-01-03T04:07:04Z', 'xuewenqi'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270065461', '2017-01-03T08:02:13Z', 'Yifan127'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270066248', '2017-01-03T08:10:11Z', 'Yzlovekid'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270074777', '2017-01-03T09:20:27Z', 'tcfh2016'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270115452', '2017-01-03T13:37:06Z', 'SophieXS'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270116222', '2017-01-03T13:41:18Z', 'starsCX'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270126246', '2017-01-03T14:31:35Z', 'Lesley19'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270336477', '2017-01-04T10:07:51Z', 'Irene6161'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270834165', '2017-01-06T05:24:33Z', 'tcfh2016'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270961941', '2017-01-06T17:53:47Z', 'Vernunftsoft'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/271086688', '2017-01-07T14:25:40Z', 'fandongdong89'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/271125504', '2017-01-08T02:48:21Z', 'sophiefschen'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/271145642', '2017-01-08T11:38:23Z', 'shereb'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/271299902', '2017-01-09T14:38:46Z', 'elsaxxx']]
# 4
# [['https://api.github.com/repos/AIMinder/Py103/issues/comments/269875014', '2016-12-31T17:39:05Z', 'summerpenguin'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269895726', '2017-01-01T08:32:35Z', '17days'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269897530', '2017-01-01T09:57:40Z', 'sardine2'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269903024', '2017-01-01T13:27:49Z', 'lsl1415'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269949821', '2017-01-02T09:36:53Z', 'lying87'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269952416', '2017-01-02T10:04:08Z', 'Twanjun'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269963353', '2017-01-02T11:56:30Z', 'mxclover'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269995912', '2017-01-02T16:53:11Z', 'scratlzj'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270048511', '2017-01-03T03:52:51Z', 'gogu'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270051004', '2017-01-03T04:34:09Z', 'hwast'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270051985', '2017-01-03T04:52:40Z', 'HenryLGL'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270266824', '2017-01-04T00:43:26Z', 'ceciliacheng'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270636039', '2017-01-05T12:44:46Z', 'panfeng3141'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270658487', '2017-01-05T14:38:21Z', 'shi1234'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/271130063', '2017-01-08T04:58:02Z', 'guoyuming'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/271768002', '2017-01-11T03:24:37Z', 'ishanshan']]
# 5
# [['https://api.github.com/repos/AIMinder/Py103/issues/comments/269791208', '2016-12-30T16:28:51Z', 'maokaiqi'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269889429', '2017-01-01T02:02:41Z', '513572509'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269890640', '2017-01-01T03:08:14Z', 'fatfox2016'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269895138', '2017-01-01T07:57:16Z', 'xbaiyuan'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269905730', '2017-01-01T14:50:17Z', 'alice7706'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269905940', '2017-01-01T14:55:56Z', 'vanxv'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269909334', '2017-01-01T16:26:07Z', 'hsdiamhsd894'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269910559', '2017-01-01T17:02:01Z', 'code661'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269911104', '2017-01-01T17:17:15Z', 'NBR-hugh'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269944982', '2017-01-02T08:38:22Z', 'hsdiamhsd894'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/269968974', '2017-01-02T12:54:46Z', 'stuian'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270029894', '2017-01-02T23:05:27Z', 'luckysilly'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270053621', '2017-01-03T05:22:25Z', 'cicei'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270302272', '2017-01-04T06:18:23Z', 'MagicCheng'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270311072', '2017-01-04T07:39:25Z', 'hstaoqian'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/271067698', '2017-01-07T06:59:21Z', 'tamuleifan'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/271767378', '2017-01-11T03:19:42Z', 'ishanshan']]
# 8
# []
# 9
# [['https://api.github.com/repos/AIMinder/Py103/issues/comments/270053815', '2017-01-03T05:26:20Z', 'ishanshan'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270054728', '2017-01-03T05:42:13Z', 'maokaiqi'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270055063', '2017-01-03T05:47:43Z', 'ishanshan'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270055427', '2017-01-03T05:53:45Z', 'maokaiqi'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/270060407', '2017-01-03T07:05:49Z', 'sunoonlee'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/271827561', '2017-01-11T10:02:50Z', 'serena333'], ['https://api.github.com/repos/AIMinder/Py103/issues/comments/271829549', '2017-01-11T10:11:49Z', 'serena333']]
# 10
